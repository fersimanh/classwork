# %% [markdown]
# ### Python Programming Concepts

# %% [markdown]
# #### 1. Create a variable to store the value 500 for sales

# %%
sales = 500
sales

# %% [markdown]
# #### 2. Create a variable to store several values:
# * sales: 500, 475, 625
# * integers 1 - 9

# %%
sales = [500, 475, 625]
sales.pop()
# Out:
# 625

# %%
integers = list(range(10,1,-1))
integers
# Out:
# [10, 9, 8, 7, 6, 5, 4, 3, 2]

# %% [markdown]
# #### 3. Create a variable to store the names and email addresses for a number of customers
# * John, john@some.com; Ann, ann@some.com

# %%
John = "john@some.com"
Ann = "ann@some.com"

# %% [markdown]
# #### 4. Use Python to generate a random value based on each of following:
# 1. between 0 and 1
# 2. the standard normal distribution (rounded to two decimal places)
# 3. a value between 1 and 10
# 4. either H or T

# %%
import random

# 1. a random value between 0 and 1
random.random()
# Out:
# 0.13601123982708363

# %%
# 2. a value from the standard normal distribution, rounded to two decimal places
round(random.gauss(0, 1), 2)
# Out:
# -0.54

# %%
# 3. a value between 1 and 10
random.randint(1, 10)
# Out:
# 5

# %%
# 4. either H or T (like a coin flip)
random.choice(["H", "T"])
# Out:
# 'T'

# %% [markdown]
# #### 5. Use Python to determine your current working directory

# %%
import os

os.getcwd()
# Out:
# '/Users/fersiman/Documents/classwork/OIM3641_F26'

# %% [markdown]
# #### 6. Use Python to determine how many days until New Year's Day

# %%
from datetime import date

today = date.today()
new_years_day = date(today.year + 1, 1, 1)   # Jan 1 of next year
days_until = (new_years_day - today).days
days_until
# Out:
# 119

# %% [markdown]
# #### 7. Write a short program that displays the future value of 1,000 earning 5%  at the end of each year for the next 5 years

# %%
present_value = 1000
rate = 0.05

for year in range(1, 6):
    future_value = present_value * (1 + rate) ** year
    print(f"Year {year}: {future_value:.2f}")
# Out:
# Year 1: 1050.00
# Year 2: 1102.50
# Year 3: 1157.63
# Year 4: 1215.51
# Year 5: 1276.28

# %% [markdown]
# #### 8. Write a short program that prompts a user to enter a stock symbol and press enter. Add each symbol entered to a variable. The program should run until the user presses the enter key without entering anything (empty string)

# %%
symbols = []

while True:
    symbol = input("Enter a stock symbol (press Enter alone to stop): ")
    if symbol == "":
        break
    symbols.append(symbol)

symbols
# Out:
# ['AAPL', 'MSFT']

# %% [markdown]
# #### 9. Write the code necessary to calculate the sum of the square differences of a group of values :
# 58, 32, 37, 41, 36, 36, 54, 37, 25, 53
# ##### $\Sigma $(${x}$ - $\bar{x}$)$^2$

# %%
values = [58, 32, 37, 41, 36, 36, 54, 37, 25, 53]

mean = sum(values) / len(values)

sum_sq_diff = 0
for x in values:
    sum_sq_diff += (x - mean) ** 2

sum_sq_diff
# Out:
# 1020.9000000000001

# %% [markdown]
# #### 10. Opening, reading and writing files

# %%
# writing to a file
with open("demo.txt", "w") as f:
    f.write("Hello\n")
    f.write("This is a test file.\n")
# the file is automatically closed once we leave the "with" block

# reading it back
with open("demo.txt", "r") as f:
    contents = f.read()

print(contents)

# %% [markdown]
# #### 11. Create a function the will simulate rolling two die and return the value of each and and the sum

# %%
def roll_two_dice():
    die1 = random.randint(1, 6)
    die2 = random.randint(1, 6)
    total = die1 + die2
    return die1, die2, total

roll_two_dice()
# Out:
# (4, 3, 7)

# %% [markdown]
# #### 12. Write the code needed to evaluate whether a value in a group of values is negative or postive and prints an approriate message, i.e. postive, negative
# -1.59, 2.36, 1.69, 1.13, -0.91, 1.48, -0.34, 1.31, -0.74, 0.2

# %%
values = [-1.59, 2.36, 1.69, 1.13, -0.91, 1.48, -0.34, 1.31, -0.74, 0.2]

for x in values:
    if x > 0:
        print(f"{x} is positive")
    elif x < 0:
        print(f"{x} is negative")
    else:
        print(f"{x} is zero")
# Out:
# -1.59 is negative
# 2.36 is positive
# 1.69 is positive
# 1.13 is positive
# -0.91 is negative
# 1.48 is positive
# -0.34 is negative
# 1.31 is positive
# -0.74 is negative
# 0.2 is positive

# %% [markdown]
# #### 14.  Complete the following:
# 1. Write a program that generates 500 random integers from 1 to n, for example, the first integer will be 1 the second will be 1 or 2, the fifth between 1 and 5, and so on.
# 2. The program should write each integer to a file
# 3. Once all integers are written close the file
#
# ##### Part 2
# 1. Open and read the file into a list
# 2. Create a line plot of the data

# %%
# Part 1: generate 500 random integers and write them to a file
with open("random_integers.txt", "w") as f:
    for i in range(1, 501):
        value = random.randint(1, i)
        f.write(str(value) + "\n")
# file is automatically closed here, once we leave the "with" block

# %%
# Part 2, step 1: open and read the file back into a list
data = []
with open("random_integers.txt", "r") as f:
    for line in f:
        data.append(int(line.strip()))

data[:10]   # just peek at the first 10 to sanity-check
# Out:
# [1, 2, 3, 4, 1, 1, 3, 7, 5, 9]

# %%
# Part 2, step 2: line plot of the data
import matplotlib.pyplot as plt

plt.plot(data)
plt.xlabel("Index")
plt.ylabel("Random Value")
plt.title("500 Random Integers (growing range)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 2
#       1 # Part 2, step 2: line plot of the data
# ----> 2 import matplotlib.pyplot as plt
#       4 plt.plot(data)
#       5 plt.xlabel("Index")
#
# ModuleNotFoundError: No module named 'matplotlib'
